# %% [markdown]
# ## Data Enrichment with AI

# %% [markdown]
# ### Setup

# %% [markdown]
# ##### Create a dataset for storing the AI tables and another for storing the AI models

# %%
# %%bigquery
# CREATE SCHEMA `cs329e-sp2024`.airline_stg_ai
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# CREATE SCHEMA `cs329e-sp2024`.remote_models
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ##### Before running this cell, create the remote connection and assign the IAM role `Vertex AI User` to the service account associated with the connection.

# %%
# %%bigquery
# create or replace model remote_models.gemini_pro
#   remote with connection `projects/cs329e-sp2024/locations/us/connections/vertex_connection`
#   options (endpoint = 'gemini-pro');
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Part 1: Predict the subcategory of a snack

# %%
# %%bigquery
# select * except (image_url, created_time, last_modified_time, data_source, load_time)
# from airline_stg.Snack
# where ingredients_text is not null
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         snack_id                                                url  \
# 0   660901066729  http://world-en.openfoodfacts.org/product/0660...
# 1   815369010542  http://world-en.openfoodfacts.org/product/0815...
# 2  5059512742484  http://world-en.openfoodfacts.org/product/5059...
# 3  8906125471782  http://world-en.openfoodfacts.org/product/8906...
# 4  7311041080993  http://world-en.openfoodfacts.org/product/7311...
#
#                       product_name    brands categories countries_en  \
# 0        Chocolate Chip Walnut bar  WellBean     Snacks         None
# 1  Cheddar Cheese Baked Corn Curls     Cadia     Snacks         None
# 2   10 Meat Free Bangers in Duvets     Tesco     Snacks         None
# 3                      Finger Stix      Star     Snacks         None
# 4                             None      None     snacks         None
#
#                                     ingredients_text
# 0  ORGANIC DATES, NAVY BEANS, WALNUTS, ALMONDS, O...
# 1  CORNMEAL, EXPELLER PRESSED VEGETABLE OIL (SUNF...
# 2  Water, Wheat Flour (Wheat Flour, Calcium Carbo...
# 3  Corn Flour, Potato Powder, Refined Palmolein O...
# 4  Hvetemel, salt 3,6 %, rapsolje, surhetsreguler...

# %% [markdown]
# #### Test the generate_text function

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest a subcategory for each snack. Return the output as json, include the snack_id in the output";
# select *
# from ML.generate_text(
#   model remote_models.gemini_pro,
#   (
#     select concat(prompt_query, to_json_string(json_object("snack_id", snack_id, "url", url,
#                   "brands", brands, "product_name", product_name, "categories", categories,
#                   "ingredients_text", ingredients_text))) as prompt
#     from airline_stg.Snack
#     order by snack_id
#     limit 10
#   ),
#   struct(TRUE as flatten_json_output)
# );
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  ```json\n{\n  "snacks": [\n    {\n      "snack...
# 1  ```json\n{\n  "brands": "Coup de Pâtes",\n  "c...
# 2  ```json\n{\n  "brands": "CANDY FLOSS",\n  "cat...
# 3  ```json\n{\n  "snack_id": "1.0500016938604001e...
# 4  ```json\n{\n  "brands": null,\n  "categories":...
# 5  ```json\n{\n  "brands": null,\n  "categories":...
# 6  ```json\n{\n  "Botanas": {\n    "snack_id": "1...
# 7  ```json\n{\n  "brands": null,\n  "categories":...
# 8  ```json\n{\n  "brands": null,\n  "categories":...
# 9  ```json\n{\n  "snacks": {\n    "subcategory": ...
#
#   ml_generate_text_rai_result ml_generate_text_status  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
#
#                                               prompt
# 0  Suggest a subcategory for each snack. Return t...
# 1  Suggest a subcategory for each snack. Return t...
# 2  Suggest a subcategory for each snack. Return t...
# 3  Suggest a subcategory for each snack. Return t...
# 4  Suggest a subcategory for each snack. Return t...
# 5  Suggest a subcategory for each snack. Return t...
# 6  Suggest a subcategory for each snack. Return t...
# 7  Suggest a subcategory for each snack. Return t...
# 8  Suggest a subcategory for each snack. Return t...
# 9  Suggest a subcategory for each snack. Return t...

# %% [markdown]
# #### Tweak the prompt and save the output
# ##### [More details](https://cloud.google.com/bigquery/docs/generate-text#generate_text_from_text_data_by_using_a_prompt_from_a_query) on `ML.generate_text` parameters

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest a subcategory for each snack. Return the output as json, include only the snack_id and subcategory in the output";
# create or replace table airline_stg_ai.subcategory_predictions_raw_10 as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#       select concat(prompt_query, to_json_string(json_object("snack_id", snack_id, "url", url,
#                   "brands", brands, "product_name", product_name, "categories", categories,
#                   "ingredients_text", ingredients_text))) as prompt
#       from airline_stg.Snack
#       order by snack_id
#       limit 10
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select ml_generate_text_llm_result, prompt
# from airline_stg_ai.subcategory_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  ```json\n{\n  "snack_id": "1.0841214700531211e...
# 1  ```json\n{\n  "snack_id": "1.084105251179851e+...
# 2  ```json\n{"snack_id":"1.0479006121e+19","subca...
# 3  ```json\n{\n  "snack_id": "1.084105252184841e+...
# 4  ```json\n{"snack_id":"1","subcategory":"Cookie...
# 5  ```json\n{\n  "snack_id": "1.036043802595381e+...
# 6  ```json\n{\n  "snack_id": "1.0500016938604001e...
# 7  ```json\n{\n  "snack_id": "1.0841052523204611e...
# 8  ```json\n{\n  "snack_id": "1.0843506381328111e...
# 9  ```json\n{\n  "snack_id": "1.0841052512999511e...
#
#                                               prompt
# 0  Suggest a subcategory for each snack. Return t...
# 1  Suggest a subcategory for each snack. Return t...
# 2  Suggest a subcategory for each snack. Return t...
# 3  Suggest a subcategory for each snack. Return t...
# 4  Suggest a subcategory for each snack. Return t...
# 5  Suggest a subcategory for each snack. Return t...
# 6  Suggest a subcategory for each snack. Return t...
# 7  Suggest a subcategory for each snack. Return t...
# 8  Suggest a subcategory for each snack. Return t...
# 9  Suggest a subcategory for each snack. Return t...

# %% [markdown]
# #### Format the output to proper json

# %%
# %%bigquery
# select ml_generate_text_llm_result, trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as formated_result
# from airline_stg_ai.subcategory_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  ```json\n{\n  "snack_id": "1.0841214700531211e...
# 1  ```json\n{\n  "snack_id": "1.084105251179851e+...
# 2  ```json\n{"snack_id":"1.0479006121e+19","subca...
# 3  ```json\n{\n  "snack_id": "1.084105252184841e+...
# 4  ```json\n{"snack_id":"1","subcategory":"Cookie...
# 5  ```json\n{\n  "snack_id": "1.036043802595381e+...
# 6  ```json\n{\n  "snack_id": "1.0500016938604001e...
# 7  ```json\n{\n  "snack_id": "1.0841052523204611e...
# 8  ```json\n{\n  "snack_id": "1.0843506381328111e...
# 9  ```json\n{\n  "snack_id": "1.0841052512999511e...
#
#                                      formated_result
# 0  {  "snack_id": "1.0841214700531211e+20",  "sub...
# 1  {  "snack_id": "1.084105251179851e+21",  "subc...
# 2  {"snack_id":"1.0479006121e+19","subcategory":"...
# 3  {  "snack_id": "1.084105252184841e+21",  "subc...
# 4           {"snack_id":"1","subcategory":"Cookies"}
# 5  {  "snack_id": "1.036043802595381e+43",  "subc...
# 6  {  "snack_id": "1.0500016938604001e+19",  "sub...
# 7  {  "snack_id": "1.0841052523204611e+21",  "sub...
# 8  {  "snack_id": "1.0843506381328111e+21",  "sub...
# 9  {  "snack_id": "1.0841052512999511e+21",  "sub...

# %%
# %%bigquery
# create or replace table airline_stg_ai.subcategory_predictions_formatted_10 as
#   select trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
#   from airline_stg_ai.subcategory_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select json_value(ml_generate_text_llm_result, '$.snack_id') as snack_id,
#   json_value(ml_generate_text_llm_result, '$.subcategory') as subcategory
# from airline_stg_ai.subcategory_predictions_formatted_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                  snack_id        subcategory
# 0  1.0841214700531211e+20            Bonbons
# 1  1.0843506381328111e+21            Bonbons
# 2        1.0479006121e+19        CANDY FLOSS
# 3  1.0500016938604001e+19      Sausage rolls
# 4                       1            Cookies
# 5  1.0841052512999511e+21            Bonbons
# 6  1.0841052523204611e+21            Botanas
# 7   1.084105251179851e+21          Golosinas
# 8   1.036043802595381e+43  Pains aux raisins
# 9   1.084105252184841e+21          Golosinas

# %% [markdown]
# #### Add the subcategory field to the Snack table

# %%
# %%bigquery
# alter table airline_stg.Snack add column subcategory string;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Update the Snack records with the predicted subcategory

# %%
# %%bigquery
# update airline_stg.Snack set subcategory =
#   (select json_value(ml_generate_text_llm_result, '$.subcategory')
#    from airline_stg_ai.subcategory_predictions_formatted_10
#    where snack_id = json_value(ml_generate_text_llm_result, '$.snack_id'))
# where 1=1
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Inspect the output

# %%
# %%bigquery
# select * except(url, image_url, created_time, last_modified_time, data_source, load_time)
# from airline_stg.Snack
# where subcategory is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                  snack_id                                   product_name  \
# 0                       1                                    Test Cookie
# 1  1.0841052523204611e+21                                       Fini Fun
# 2   1.084105251179851e+21                             Abichuela golisina
# 3   1.084105252184841e+21                               Geles dulce pica
# 4        1.0479006121e+19                                    Zuckerwatte
# 5  1.0841214700531211e+20                                         Bonbon
# 6  1.0841052512999511e+21                      Confiserie gélifiée mures
# 7  1.0843506381328111e+21                             Cintas pica sandia
# 8  1.0500016938604001e+19                Outdoor Bred Pork Sausage Rolls
# 9   1.036043802595381e+43  60 Pains aux Raisins Prépoussés au Beurre Fin
#
#           brands                                         categories  \
# 0            MTR                                             Snacks
# 1           None                     Botanas, Snacks dulces, Dulces
# 2           None          Botanas, Snacks dulces, Dulces, Golosinas
# 3           Fini          Botanas, Snacks dulces, Dulces, Golosinas
# 4    CANDY FLOSS        Snacks,Sweet snacks,Confectioneries,Candies
# 5           None        Snacks, Snacks sucrés, Confiseries, Bonbons
# 6           None        Snacks, Snacks sucrés, Confiseries, Bonbons
# 7     King Regal        Snacks, Snacks sucrés, Confiseries, Bonbons
# 8       Waitrose    Snacks, Salty snacks, Appetizers, Sausage rolls
# 9  Coup de Pâtes  Snacks, Snacks sucrés, Surgelés, Viennoiseries...
#
#   countries_en                                   ingredients_text  \
# 0      Ukraine                                               None
# 1        Spain                                               None
# 2        Spain                                               None
# 3        Spain                                               None
# 4      Germany         Zucker, Aroma, Farbstoffe E100, E120, E133
# 5       France                   Colorants : E-100, E-120, E-133.
# 6       France                                               None
# 7       France                                               None
# 8    Singapore  pork (40%), fortified wheat flour (_wheat_ flo...
# 9       France  Pâte (60.9 %) Farine de _blé_, _beurre_ fin 26...
#
#          subcategory
# 0            Cookies
# 1            Botanas
# 2          Golosinas
# 3          Golosinas
# 4        CANDY FLOSS
# 5            Bonbons
# 6            Bonbons
# 7            Bonbons
# 8      Sausage rolls
# 9  Pains aux raisins

# %% [markdown]
# #### Apply at larger scale

# %% [markdown]
# Gemini-pro is slow, it would take **3.7 hours** to process 226780 rows in the Snack table based on a 1000 QPM limit (226780/1000 = 227 min).
#
# And the default quota is only 300 QPM in us-central1.
#
# To process larger volumes, we can request a quota increaseby following these steps:
# - Go to the [Quota page](https://console.cloud.google.com/iam-admin/quotas)
# - Click on "Generate content requests per minute per project per base model per minute per region per base_model" for us-central1 and gemini-pro
# -Click the Edit Quotas button
# -In the new value field, enter 1000
# -In the justification field, enter "To process a 226780 row table"
# -Click Next until you get to the last page
# -Click Submit
# -Wait for a few minutes, you should get an email once it's been approved. Usually takes ~5 minutes.

# %% [markdown]
# ###### Create a smaller Snack table with 10K records in order to finish within 30 minutes

# %%
# %%bigquery
# create or replace table airline_stg.Snack_10k as
#   select *
#   from airline_stg.Snack
#   where brands is not null
#   and categories is not null
#   and ingredients_text is not null
#   and countries_en is not null
#   limit 10000
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select *
# from airline_stg.Snack_10k
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#            snack_id                                                url  \
# 0     3256225732111  http://world-en.openfoodfacts.org/product/3256...
# 1     3256224160502  http://world-en.openfoodfacts.org/product/3256...
# 2     3256221212266  http://world-en.openfoodfacts.org/product/3256...
# 3     3256229522022  http://world-en.openfoodfacts.org/product/3256...
# 4     3256225732104  http://world-en.openfoodfacts.org/product/3256...
# ...             ...                                                ...
# 9995    37323118785  http://world-en.openfoodfacts.org/product/0037...
# 9996    37323115821  http://world-en.openfoodfacts.org/product/0037...
# 9997    37323118709  http://world-en.openfoodfacts.org/product/0037...
# 9998  8606012185067  http://world-en.openfoodfacts.org/product/8606...
# 9999  7610095128904  http://world-en.openfoodfacts.org/product/7610...
#
#                                 product_name  \
# 0     Cacahuètes enrobées saveur sweet chili
# 1        Tourte Champignons - surgelée 500 g
# 2              Noix de cajou grillées salées
# 3                               Snack poppés
# 4          Cacahuètes enrobées saveur wasabi
# ...                                      ...
# 9995                             Apple Sauce
# 9996                             Apple sauce
# 9997  Musselman's, lite original apple sauce
# 9998                 Rocky rice choco orange
# 9999     Kezz Chips Indian Pepper & Sea Salt
#
#                                  brands  \
# 0                                     U
# 1                                     U
# 2                                     U
# 3                                     U
# 4                                     U
# ...                                 ...
# 9995                 Knouse Foods  Inc.
# 9996                 Knouse Foods  Inc.
# 9997                 Knouse Foods  Inc.
# 9998               Benlian Food,Benlian
# 9999  Zweifel, Zweifel KEZZ Kesselchips
#
#                                              categories  \
# 0     Aliments et boissons à base de végétaux, Alime...
# 1     Snacks, Snacks salés, Amuse-gueules, Surgelés,...
# 2     Aliments et boissons à base de végétaux, Alime...
# 3                                                Snacks
# 4     Aliments et boissons à base de végétaux, Alime...
# ...                                                 ...
# 9995                                             Snacks
# 9996                                             Snacks
# 9997                                             Snacks
# 9998  Plant-based foods and beverages, Plant-based f...
# 9999  Plant-based foods and beverages, Plant-based f...
#
#                                            countries_en  \
# 0                                                France
# 1                                                France
# 2                                                France
# 3                                                France
# 4                                                France
# ...                                                 ...
# 9995                                      United States
# 9996                                      United States
# 9997                                      United States
# 9998                         France,Hungary,Netherlands
# 9999  Austria,France,Switzerland,World,Deutschland,F...
#
#                                        ingredients_text  \
# 0     CACAHUÈTES 72%, farine de BLÉ, amidon de pomme...
# 1     Pâte 50 % : farine de blé, margarine (graisses...
# 2     NOIX DE CAJOU 96%, huile de tournesol, sel 1%....
# 3     Riz rond, fécule de pommes de terre, pois cass...
# 4     CACAHUÈTES 71%, farine de BLÉ, amidon de pomme...
# ...                                                 ...
# 9995  Apples, water, ascorbic acid to maintain color...
# 9996  Apples, sugar, water, lemon juice and cinnamon...
# 9997  Apples, water, ascorbic acid to maintain color...
# 9998  chocolate coating 68% (sugar, cocoa butter*, c...
# 9999  Kartoffeln, Rapsöl 25%, Gewürzzubereitung (Rei...
#
#                                               image_url  \
# 0     https://images.openfoodfacts.org/images/produc...
# 1     https://images.openfoodfacts.org/images/produc...
# 2     https://images.openfoodfacts.org/images/produc...
# 3     https://images.openfoodfacts.org/images/produc...
# 4     https://images.openfoodfacts.org/images/produc...
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
#                   created_time        last_modified_time      data_source  \
# 0    2017-03-06 16:46:30+00:00 2020-09-15 17:14:12+00:00  open_food_facts
# 1    2013-05-26 14:09:26+00:00 2022-02-11 04:14:22+00:00  open_food_facts
# 2    2015-11-10 16:49:31+00:00 2023-06-07 10:25:49+00:00  open_food_facts
# 3    2023-05-08 11:10:56+00:00 2023-11-20 02:27:04+00:00  open_food_facts
# 4    2017-11-11 14:16:30+00:00 2023-03-07 09:41:20+00:00  open_food_facts
# ...                        ...                       ...              ...
# 9995 2017-03-09 12:33:32+00:00 2020-04-22 17:57:47+00:00  open_food_facts
# 9996 2017-03-09 12:13:32+00:00 2020-04-22 17:46:13+00:00  open_food_facts
# 9997 2017-03-09 12:33:32+00:00 2020-04-22 17:57:47+00:00  open_food_facts
# 9998 2018-07-30 13:50:51+00:00 2023-08-07 07:20:15+00:00  open_food_facts
# 9999 2022-03-02 14:30:59+00:00 2023-07-16 13:07:48+00:00  open_food_facts
#
#                             load_time subcategory
# 0    2024-02-03 19:40:10.880358+00:00        None
# 1    2024-02-03 19:40:10.880358+00:00        None
# 2    2024-02-03 19:40:10.880358+00:00        None
# 3    2024-02-03 19:40:10.880358+00:00        None
# 4    2024-02-03 19:40:10.880358+00:00        None
# ...                               ...         ...
# 9995 2024-02-03 19:40:10.880358+00:00        None
# 9996 2024-02-03 19:40:10.880358+00:00        None
# 9997 2024-02-03 19:40:10.880358+00:00        None
# 9998 2024-02-03 19:40:10.880358+00:00        None
# 9999 2024-02-03 19:40:10.880358+00:00        None
#
# [10000 rows x 13 columns]

# %%
# %%bigquery
# declare prompt_query STRING default "Suggest a subcategory for each snack. Return the output as json, include only the snack_id and subcategory in the output";
# create or replace table airline_stg_ai.subcategory_predictions_raw_10k as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#       select concat(prompt_query, to_json_string(json_object("snack_id", snack_id, "url", url,
#                   "brands", brands, "product_name", product_name, "categories", categories,
#                   "ingredients_text", ingredients_text))) as prompt
#       from airline_stg.Snack_10k
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select creation_time, end_time, query
# from `region-us`.INFORMATION_SCHEMA.JOBS
# where job_id = 'a441f6b3-d6b4-4b33-a8f0-30e044e7b326'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                      creation_time                         end_time  \
# 0 2024-04-05 16:31:53.551000+00:00 2024-04-05 18:33:45.166000+00:00
#
#                                                query
# 0  declare prompt_query STRING default "Suggest a...

# %% [markdown]
# ##### It actually took 2 hours to process the 10k table. This is with only a 300 QPM, without a quota increase

# %%
# %%bigquery
# create or replace table airline_stg_ai.subcategory_predictions_formatted_10k as
#   select trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
#   from airline_stg_ai.subcategory_predictions_raw_10k;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*) as subcategory_count
# from airline_stg_ai.subcategory_predictions_formatted_10k
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    subcategory_count
# 0              10000

# %%
# %%bigquery
# update airline_stg.Snack s
#   set subcategory = json_value(p.ml_generate_text_llm_result, '$.subcategory')
#   from airline_stg_ai.subcategory_predictions_formatted_10k p
#   where s.snack_id = json_value(p.ml_generate_text_llm_result, '$.snack_id');
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*) as subcategory_count
# from airline_stg.Snack
# where subcategory is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    subcategory_count
# 0               9081

# %%
# %%bigquery
# select categories, subcategory, count(*) as count
# from airline_stg.Snack
# where subcategory is not null
# group by categories, subcategory
# order by count(*) desc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                              categories           subcategory  \
# 0           Snacks, Snacks sucrés, Confiseries, Bonbons               Bonbons
# 1     Botanas, Snacks dulces, Galletas y pasteles, G...              Galletas
# 2                   Snacks, Snacks salés, Amuse-gueules         Amuse-gueules
# 3     Botanas, Snacks dulces, en:Cocoa and its produ...     Chocolates negros
# 4                    Snacks, Snacks sucrés, Confiseries           Confiseries
# ...                                                 ...                   ...
# 2752      Snacks, Snacks salés, Chips et frites, Frites                Frites
# 2753       Snacks, Snacks sucrés, Barres, Barre sucrées          Barre sucrée
# 2754        Snacks, Snacks sucrés, Produits déshydratés  Produits déshydratés
# 2755  Snacks, Snacks sucrés, Surgelés, Viennoiseries...     Pains aux raisins
# 2756        Snacks,Sweet snacks,Confectioneries,Candies           CANDY FLOSS
#
#       count
# 0       957
# 1       189
# 2       160
# 3       155
# 4       152
# ...     ...
# 2752      1
# 2753      1
# 2754      1
# 2755      1
# 2756      1
#
# [2757 rows x 3 columns]

# %%
# %%bigquery
# update airline_stg.Snack
#   set data_source = 'open_food_facts_ai' where subcategory is not null
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Part 2: Detect the language of the snack product (English, Spanish, Japanese, etc.)

# %% [markdown]
# #### Experiment with prompt

# %%
# %%bigquery
# declare prompt_query STRING default "Detect the language of the text. For example, English, French, Spanish, etc. Return the output as json, include the snack_id in the output as well";
# select *
# from ML.generate_text(
#   model remote_models.gemini_pro,
#   (
#     select concat(prompt_query, to_json_string(json_object("snack_id", snack_id, "product_name", product_name,
#                   "brands", brands, "categories", categories, "ingredients_text", ingredients_text))) as prompt
#     from airline_stg.Snack_10k
#     order by snack_id
#     limit 10
#   ),
#   struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
# );
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  {"language": "English", "snack_id": "1.6128354...
# 1  ```json\n{"language": "English", "snack_id": "...
# 2    {"language":"English","snack_id":"10300048947"}
# 3  ```json\n{\n  "language": "English",\n  "snack...
# 4  ```json\n{\n  "language": "English",\n  "snack...
# 5  ```json\n{\n  "language": "English",\n  "snack...
# 6  {"language": "English", "snack_id": "103000654...
# 7  {"language": "English", "snack_id": "103001063...
# 8  {"language": "English", "snack_id": "103001064...
# 9  ```json\n{"language": "English", "snack_id": "...
#
#   ml_generate_text_rai_result ml_generate_text_status  \
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# 5                        None
# 6                        None
# 7                        None
# 8                        None
# 9                        None
#
#                                               prompt
# 0  Detect the language of the text. For example, ...
# 1  Detect the language of the text. For example, ...
# 2  Detect the language of the text. For example, ...
# 3  Detect the language of the text. For example, ...
# 4  Detect the language of the text. For example, ...
# 5  Detect the language of the text. For example, ...
# 6  Detect the language of the text. For example, ...
# 7  Detect the language of the text. For example, ...
# 8  Detect the language of the text. For example, ...
# 9  Detect the language of the text. For example, ...

# %%
# %%bigquery
# declare prompt_query STRING default "Detect the language of the text. For example, English, French, Spanish, etc. Return the output as json, include the snack_id in the output as well";
# create or replace table airline_stg_ai.language_predictions_raw_10 as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#       select concat(prompt_query, to_json_string(json_object("snack_id", snack_id, "product_name", product_name,
#                   "brands", brands, "categories", categories, "ingredients_text", ingredients_text))) as prompt
#       from airline_stg.Snack_10k
#       order by snack_id
#       limit 10
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select ml_generate_text_llm_result, prompt
# from airline_stg_ai.language_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result  \
# 0  {"language": "English", "snack_id": "1.6128354...
# 1  ```json\n{"language": "English", "snack_id": "...
# 2  {"language": "English", "snack_id": "103001064...
# 3  ```json\n{"language": "English", "snack_id": "...
# 4  {"language": "English", "snack_id": "103001063...
# 5  ```json\n{\n  "language": "English",\n  "snack...
# 6  ```json\n{\n  "language": "English",\n  "snack...
# 7    {"language":"English","snack_id":"10300048947"}
# 8  {"language": "English", "snack_id": "103000654...
# 9  ```json\n{\n  "language": "English",\n  "snack...
#
#                                               prompt
# 0  Detect the language of the text. For example, ...
# 1  Detect the language of the text. For example, ...
# 2  Detect the language of the text. For example, ...
# 3  Detect the language of the text. For example, ...
# 4  Detect the language of the text. For example, ...
# 5  Detect the language of the text. For example, ...
# 6  Detect the language of the text. For example, ...
# 7  Detect the language of the text. For example, ...
# 8  Detect the language of the text. For example, ...
# 9  Detect the language of the text. For example, ...

# %%
# %%bigquery
# create or replace table airline_stg_ai.language_predictions_formatted_10 as
#   select trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
#   from airline_stg_ai.language_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select * from airline_stg_ai.language_predictions_formatted_10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          ml_generate_text_llm_result
# 0  {"language": "English", "snack_id": "103001063...
# 1  {"language": "English", "snack_id": "103001064...
# 2  {  "language": "English",  "snack_id": "103000...
# 3  {"language": "English", "snack_id": "1.6128354...
# 4  {"language": "English", "snack_id": "103000654...
# 5  {  "language": "English",  "snack_id": "103000...
# 6  {  "language": "English",  "snack_id": "103000...
# 7    {"language":"English","snack_id":"10300048947"}
# 8  {"language": "English", "snack_id": "102864500...
# 9  {"language": "English", "snack_id": "103001415...

# %%
# %%bigquery
# alter table airline_stg.Snack add column language string;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# update airline_stg.Snack set language =
#   (select json_value(ml_generate_text_llm_result, '$.language')
#    from airline_stg_ai.language_predictions_formatted_10
#    where snack_id = json_value(ml_generate_text_llm_result, '$.snack_id'))
# where 1=1;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select * except(image_url, created_time, last_modified_time, data_source, load_time)
# from airline_stg.Snack_10k
# where language is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                 snack_id                                                url  \
# 0            10300048947  http://world-en.openfoodfacts.org/product/0010...
# 1            10300141518  http://world-en.openfoodfacts.org/product/0010...
# 2            10300106395  http://world-en.openfoodfacts.org/product/0010...
# 3            10300106494  http://world-en.openfoodfacts.org/product/0010...
# 4            10300065425  http://world-en.openfoodfacts.org/product/0010...
# 5          1028645000901  http://world-en.openfoodfacts.org/product/1028...
# 6            10300064220  http://world-en.openfoodfacts.org/product/0010...
# 7            10300064213  http://world-en.openfoodfacts.org/product/0010...
# 8            10300064701  http://world-en.openfoodfacts.org/product/0010...
# 9  1.612835432630006e+19  http://world-en.openfoodfacts.org/product/1612...
#
#                            product_name    brands categories  \
# 0                       Chopped Walnuts   Diamond     Snacks
# 1                  Premium Pecan Halves   Diamond     Snacks
# 2                         Glazed Pecans   Emerald     Snacks
# 3                            Mixed Nuts   Emerald     Snacks
# 4        Emerald, salt & pepper cashews   Emerald     Snacks
# 5                        Deluxe Cashews  Pardoe's     Snacks
# 6  Berry Nut Blend Breakfast In The Go!   Emerald     Snacks
# 7                     Nut & granola mix   Emerald     Snacks
# 8        Nut & granola mix snack blends   Emerald     Snacks
# 9                   Peanut Caramel Bars   Manzela     Snacks
#
#            countries_en                                   ingredients_text  \
# 0         United States                                           Walnuts.
# 1         United States                                             Pecans
# 2         United States  Pecans, sugar, corn syrup, brown sugar, natura...
# 3         United States  Glazed almonds (almonds, sugar, corn syrup, sa...
# 4         United States  Cashews, vegetable oil (safflower, sunflower, ...
# 5         United States      Cashews, peanut oil, salt. artificial flavor.
# 6         United States  Vanilla granola (rolled oats, brown sugar, whe...
# 7         United States  Vanilla granola (rolled oats, brown sugar, whe...
# 8         United States  Sea salt caramel flavored glazed almonds (almo...
# 9  Mexico,United States               Peanuts, sugar, glucose, brown sugar
#
#   subcategory language
# 0        Nuts  English
# 1        Nuts  English
# 2        Nuts  English
# 3        Nuts  English
# 4        Nuts  English
# 5        Nuts  English
# 6   Breakfast  English
# 7   Trail Mix  English
# 8   Trail Mix  English
# 9  Candy Bars  English

# %% [markdown]
# #### Apply at larger scale

# %%
# %%bigquery
# declare prompt_query STRING default "Detect the language of the text. For example, English, French, Spanish, etc. Return the output as json, include the snack_id in the output as well";
# create or replace table airline_stg_ai.language_predictions_raw_10k as
#   select *
#   from ML.generate_text(
#     model remote_models.gemini_pro,
#     (
#       select concat(prompt_query, to_json_string(json_object("snack_id", snack_id, "product_name", product_name,
#                   "brands", brands, "categories", categories, "ingredients_text", ingredients_text))) as prompt
#       from airline_stg.Snack_10k
#       order by snack_id
#     ),
#     struct(0 as temperature, 8192 as max_output_tokens, 0.0 as top_p, 1 as top_k, TRUE as flatten_json_output)
#   );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select ml_generate_text_llm_result, prompt
# from airline_stg_ai.language_predictions_raw_10k
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                             ml_generate_text_llm_result  \
# 0     {"language": "English", "snack_id": "111100323...
# 1     ```json\n{\n  "language": "English",\n  "snack...
# 2     ```json\n{\n  "language": "English",\n  "snack...
# 3       {"language":"English","snack_id":"11110914576"}
# 4     ```json\n{\n  "language": "English",\n  "snack...
# ...                                                 ...
# 9995  {"language": "English", "snack_id": "870762114...
# 9996  ```json\n{\n  "language": "English",\n  "snack...
# 9997  {"language": "English", "snack_id": "895296001...
# 9998  {"language": "English", "snack_id": "949220329...
# 9999  ```json\n{"language": "English", "snack_id": "...
#
#                                                  prompt
# 0     Detect the language of the text. For example, ...
# 1     Detect the language of the text. For example, ...
# 2     Detect the language of the text. For example, ...
# 3     Detect the language of the text. For example, ...
# 4     Detect the language of the text. For example, ...
# ...                                                 ...
# 9995  Detect the language of the text. For example, ...
# 9996  Detect the language of the text. For example, ...
# 9997  Detect the language of the text. For example, ...
# 9998  Detect the language of the text. For example, ...
# 9999  Detect the language of the text. For example, ...
#
# [10000 rows x 2 columns]

# %%
# %%bigquery
# select trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
# from airline_stg_ai.language_predictions_raw_10k
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                             ml_generate_text_llm_result
# 0     {"language": "English", "snack_id": "111100323...
# 1     {  "language": "English",  "snack_id": "111108...
# 2     {  "language": "English",  "snack_id": "111108...
# 3       {"language":"English","snack_id":"11110914576"}
# 4     {  "language": "English",  "snack_id": "111501...
# ...                                                 ...
# 9995  {"language": "English", "snack_id": "870762114...
# 9996  {  "language": "English",  "snack_id": "870762...
# 9997  {"language": "English", "snack_id": "895296001...
# 9998  {"language": "English", "snack_id": "949220329...
# 9999  {"language": "English", "snack_id": "9802802102"}
#
# [10000 rows x 1 columns]

# %%
# %%bigquery
# create or replace table airline_stg_ai.language_predictions_formatted_10k as
#   select trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
#   from airline_stg_ai.language_predictions_raw_10k
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select *
# from airline_stg_ai.language_predictions_formatted_10k
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                             ml_generate_text_llm_result
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3            {"language":"English","snack_id":"536769"}
# 4            {"language":"English","snack_id":"981477"}
# ...                                                 ...
# 9995  {"language": "English","brands":"Valued Natura...
# 9996  {"language":"Italian","brands":"Saladine","cat...
# 9997  {"language": "English","brands":"Gefen","categ...
# 9998  {"language": "English","brands":"That's It.","...
# 9999  {"language":"English","brands":"Ahold","catego...
#
# [10000 rows x 1 columns]

# %%
# %%bigquery
# alter table airline_stg.Snack add column language string;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# update airline_stg.Snack set language =
#   (select json_value(ml_generate_text_llm_result, '$.language')
#    from airline_stg_ai.language_predictions_formatted_10k
#    where snack_id = json_value(ml_generate_text_llm_result, '$.snack_id'))
# where 1=1
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select * except(url, image_url, created_time, last_modified_time, data_source, load_time)
# from airline_stg.Snack
# where language is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#            snack_id                                       product_name  \
# 0     8901565001728  Piknik Classic Tomato Chilli (fried Indian snack)
# 1     8906081129222                         Dryfruit Bar - Blueberries
# 2     8901491208291                                    Bikaneri Bhujia
# 3     8908005583189                                       cheese balls
# 4     8904406116735                           Garlic 100% Veggie Chips
# ...             ...                                                ...
# 9992  7610095128904                Kezz Chips Indian Pepper & Sea Salt
# 9993  7613036562287                       Beetroot and Apple Fruit Bar
# 9994    38000185083                                     Pringles Pizza
# 9995    38000846748                           Pringles Crema y Cebolla
# 9996    38000846755                                     Pringles Queso
#
#                                  brands  \
# 0                                Piknik
# 1                               Happilo
# 2                               Kurkure
# 3                              time out
# 4                             SnackWise
# ...                                 ...
# 9992  Zweifel, Zweifel KEZZ Kesselchips
# 9993                          Ohhh Yes!
# 9994                           Pringles
# 9995                           Pringles
# 9996                           Pringles
#
#                                              categories  \
# 0                                                Snacks
# 1                                                Snacks
# 2                                                Snacks
# 3                                                Snacks
# 4                                                Snacks
# ...                                                 ...
# 9992  Plant-based foods and beverages, Plant-based f...
# 9993                                             Snacks
# 9994  Alimentos y bebidas de origen vegetal, Aliment...
# 9995  Alimentos y bebidas de origen vegetal, Aliment...
# 9996  Alimentos y bebidas de origen vegetal, Aliment...
#
#                                            countries_en  \
# 0                                                 India
# 1                                                 India
# 2                                                 India
# 3                                                 India
# 4                                                 India
# ...                                                 ...
# 9992  Austria,France,Switzerland,World,Deutschland,F...
# 9993  Czech Republic,France,Ireland,Netherlands,Slov...
# 9994  Argentina,Bolivia,Colombia,Costa Rica,Panama,P...
# 9995  Bolivia,Colombia,Costa Rica,Dominican Republic...
# 9996  Bolivia,Colombia,Costa Rica,Dominican Republic...
#
#                                        ingredients_text subcategory language
# 0     Wheat Flour, Edible Starch, Edible Vegetable O...        None  English
# 1     Cashews, Dates, Almonds, Black Raisins, Bluebe...        None  English
# 2     Edible Vegetable Oil (Rice Brand Oil), Moth Da...        None  English
# 3     INGREDIENTS:Corn Grits, Refined Vegetable Oil,...        None  English
# 4                                 Garlic and Edible Oil        None  English
# ...                                                 ...         ...      ...
# 9992  Kartoffeln, Rapsöl 25%, Gewürzzubereitung (Rei...        None  English
# 9993  Apple juice concentrate, Apple puree, Dried ap...        None  English
# 9994  PATATAS DESHIDRATADAS, ACEITE VEGETAL (MAÍZ, S...        None  Spanish
# 9995  Papas deshidratadas, aceite vegetal, harina de...        None  Spanish
# 9996  Papas deshidratadas, aceite vegetal, harina de...        None  Spanish
#
# [9997 rows x 8 columns]

# %%
# %%bigquery
# select * except(url, image_url, created_time, last_modified_time, data_source, load_time)
# from airline_stg.Snack
# where language != "English"
# and language is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#           snack_id                    product_name      brands  \
# 0    8008620012139                 Crunchy cereals       Crich
# 1    8425514135154                            None   Mercadona
# 2    8480000341549           Cacahuete Garrapiñado   Hacendado
# 3    8480000336231                         Varitas   Hacendado
# 4    8480000333070                            None   Hacendado
# ..             ...                             ...         ...
# 305  3560071083991                   Noix de cajou   Carrefour
# 306  7501011178854  Stax con sabor a Queso Cheddar  Lay's,Stax
# 307    38000185083                  Pringles Pizza    Pringles
# 308    38000846748        Pringles Crema y Cebolla    Pringles
# 309    38000846755                  Pringles Queso    Pringles
#
#                                             categories  \
# 0    Aliments et boissons à base de végétaux, Alime...
# 1    Alimentos y bebidas de origen vegetal, Aliment...
# 2    Alimentos y bebidas de origen vegetal, Aliment...
# 3    Alimentos y bebidas de origen vegetal, Aliment...
# 4    Aliments i begudes amb base vegetal, Aliments ...
# ..                                                 ...
# 305  Aliments et boissons à base de végétaux, Alime...
# 306  Alimentos y bebidas de origen vegetal, Aliment...
# 307  Alimentos y bebidas de origen vegetal, Aliment...
# 308  Alimentos y bebidas de origen vegetal, Aliment...
# 309  Alimentos y bebidas de origen vegetal, Aliment...
#
#                                           countries_en  \
# 0                                                Italy
# 1                                                Spain
# 2                                                Spain
# 3                                                Spain
# 4                                                Spain
# ..                                                 ...
# 305          Belgium,France,Italy,Poland,Romania,Spain
# 306   Argentina,Bolivia,Mexico,Paraguay,Peru,Venezuela
# 307  Argentina,Bolivia,Colombia,Costa Rica,Panama,P...
# 308  Bolivia,Colombia,Costa Rica,Dominican Republic...
# 309  Bolivia,Colombia,Costa Rica,Dominican Republic...
#
#                                       ingredients_text subcategory language
# 0    Whole WHEAT flour 46,5%, OAT Hakes 21,2%, sunf...        None   French
# 1    Agua, harina de trigo (_gluten_) integral (30%...        None  Spanish
# 2    _Cacahuete_ 50%, azúcar, miel 1%, aromas (vain...        None  Spanish
# 3    Fécula de patata, aceite de girasol alto oleic...        None  Spanish
# 4                   potato, sunflower oil (28%), salt,        None  Spanish
# ..                                                 ...         ...      ...
# 305  _Noix de cajou_ 94,6% (origine Vietnam ou Camb...        None   French
# 306  Papas deshidratadas, aceite vegetal de maíz *,...        None  Spanish
# 307  PATATAS DESHIDRATADAS, ACEITE VEGETAL (MAÍZ, S...        None  Spanish
# 308  Papas deshidratadas, aceite vegetal, harina de...        None  Spanish
# 309  Papas deshidratadas, aceite vegetal, harina de...        None  Spanish
#
# [310 rows x 8 columns]

# %%
# %%bigquery
# update airline_stg.Snack
#   set data_source = 'open_food_facts_ai' where language is not null
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Part 3: Detect the product name of a snack from the image

# %% [markdown]
# #### Explore the raw data

# %%
# %%bigquery
# select snack_id, product_name, image_url
# from airline_stg.Snack
# where product_name is null
# and image_url is not null
# order by snack_id
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#            snack_id product_name  \
# 0        1001776768         None
# 1        1002485781         None
# 2          10107043         None
# 3           1020242         None
# 4      104770048009         None
# ...             ...          ...
# 1883  9784001372250         None
# 1884  9788426398482         None
# 1885  9788492808274         None
# 1886        9815203         None
# 1887   993094339609         None
#
#                                               image_url
# 0     https://images.openfoodfacts.org/images/produc...
# 1     https://images.openfoodfacts.org/images/produc...
# 2     https://images.openfoodfacts.org/images/produc...
# 3     https://images.openfoodfacts.org/images/produc...
# 4     https://images.openfoodfacts.org/images/produc...
# ...                                                 ...
# 1883  https://images.openfoodfacts.org/images/produc...
# 1884  https://images.openfoodfacts.org/images/produc...
# 1885  https://images.openfoodfacts.org/images/produc...
# 1886  https://images.openfoodfacts.org/images/produc...
# 1887  https://images.openfoodfacts.org/images/produc...
#
# [1888 rows x 3 columns]

# %% [markdown]
# #### Setup

# %%
# !pip install requests

# %%
import requests, os
from google.cloud import bigquery
from google.cloud import storage

bq_client = bigquery.Client()
storage_client = storage.Client()

bucket_name = "cs329e-open-access"
bucket = storage_client.get_bucket(bucket_name)

sql = "select snack_id, image_url from airline_stg.Snack where product_name is null and snack_id != '0' and image_url is not null order by snack_id limit 10"

rows = bq_client.query(sql).result()

for row in rows:
  snack_id = row["snack_id"]
  image_url = row["image_url"].strip()

  image_content = requests.get(image_url).content
  image_name = "{}.jpg".format(snack_id)
  image_file = open(image_name,'wb')
  image_file.write(image_content)
  image_file.close()

  blob = bucket.blob("images/" + image_name)
  blob.upload_from_filename("/content/" + image_name) # Colab places the downloaded image in the /content folder

  os.remove("/content/" + image_name)

# %% [markdown]
# ##### Create a remote connection for Cloud Storage before running the next cell. Assign the service account of the connection the `Storage Object Viewer` and `Vertex User` roles.

# %%
# %%bigquery
# create or replace external table airline_stg_ai.snack_product_images
# with connection `projects/cs329e-sp2024/locations/us/connections/gcs-connection`
# options(
#   object_metadata = 'SIMPLE',
#   uris = ['gs://cs329e-open-access/images/*'],
#   max_staleness = INTERVAL 1 DAY,
#   metadata_cache_mode = 'AUTOMATIC'
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select * from airline_stg_ai.snack_product_images
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                             uri        generation  \
# 0    gs://cs329e_datasets/images/1001776768.jpg  1712261719888692
# 1    gs://cs329e_datasets/images/1002485781.jpg  1712261720857749
# 2      gs://cs329e_datasets/images/10107043.jpg  1712261721717119
# 3       gs://cs329e_datasets/images/1020242.jpg  1712261722444152
# 4  gs://cs329e_datasets/images/104770048009.jpg  1712261723625406
# 5   gs://cs329e_datasets/images/10700450265.jpg  1712261724541120
# 6      gs://cs329e_datasets/images/11185352.jpg  1712261725307782
# 7   gs://cs329e_datasets/images/11300051395.jpg  1712261726187606
# 8       gs://cs329e_datasets/images/1142273.jpg  1712261726946369
# 9          gs://cs329e_datasets/images/1202.jpg  1712261727665790
#
#   content_type   size                          md5_hash  \
# 0   image/jpeg  27642  98983b825a60f39340d56dcb658ec459
# 1   image/jpeg  20589  b62a7eedfa66744603e0516d0cc0023b
# 2   image/jpeg  25728  c35b56bdacd005da4406e53d161f2e9d
# 3   image/jpeg  12504  3cf5513a9bc1c83a0d312af5583a5c10
# 4   image/jpeg  35556  318600c9a5fb1e608522e7e1223faa13
# 5   image/jpeg  46216  732c049f5c14c1f0e9ab2dbe331ac9b2
# 6   image/jpeg  26453  fdd6706a5c718b12ab66d7fcbeef32e2
# 7   image/jpeg  25176  4252019c84028b59909a9481ac389255
# 8   image/jpeg  33150  4eef7a08c079cd17b22c6f15fe1100dd
# 9   image/jpeg  25629  71622a70f7323087141ddf5ebd0aa7c8
#
#                            updated metadata
# 0 2024-04-04 20:15:19.903000+00:00       []
# 1 2024-04-04 20:15:20.868000+00:00       []
# 2 2024-04-04 20:15:21.727000+00:00       []
# 3 2024-04-04 20:15:22.455000+00:00       []
# 4 2024-04-04 20:15:23.633000+00:00       []
# 5 2024-04-04 20:15:24.555000+00:00       []
# 6 2024-04-04 20:15:25.317000+00:00       []
# 7 2024-04-04 20:15:26.202000+00:00       []
# 8 2024-04-04 20:15:26.957000+00:00       []
# 9 2024-04-04 20:15:27.677000+00:00       []

# %%
# %%bigquery
# create or replace model remote_models.gemini_pro_vision
#   remote with connection `projects/cs329e-sp2024/locations/us/connections/vertex_connection`
#   options (endpoint = 'gemini-pro-vision');
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# SELECT
#   uri,
#   ml_generate_text_llm_result
# FROM
#   ML.GENERATE_TEXT(
#     MODEL remote_models.gemini_pro_vision,
#       TABLE `cs329e-sp2024.airline_stg_ai.snack_product_images`,
#         STRUCT("What is the text in this image?" as prompt,
#           true as flatten_json_output));
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                                uri  \
# 0    gs://cs329e-open-access/images/1001776768.jpg
# 1   gs://cs329e-open-access/images/11300051395.jpg
# 2  gs://cs329e-open-access/images/104770048009.jpg
# 3       gs://cs329e-open-access/images/1142273.jpg
# 4          gs://cs329e-open-access/images/1202.jpg
# 5       gs://cs329e-open-access/images/1020242.jpg
# 6   gs://cs329e-open-access/images/10700450265.jpg
# 7    gs://cs329e-open-access/images/1002485781.jpg
# 8      gs://cs329e-open-access/images/10107043.jpg
# 9      gs://cs329e-open-access/images/11185352.jpg
#
#                          ml_generate_text_llm_result
# 0   Nestle TOPPING\nPROFESSIONAL CHOCOLATE BALLS\...
# 1   The text in this image is: "Brach's Spiced Je...
# 2   Haribo\nPandawai Pik\nSans colorant artificie...
# 3   4 Blueberry Muffins\nby Sainsbury's\n1 muffin...
# 4         The text on the image says "Coconut Rock".
# 5      The text in the image is "Cerelene Galettes".
# 6   Jolly Rancher\nSour Surge\nHard Candy with So...
# 7   MEZETE\nHUMMUS WITH BREADSTICKS\nMIDDLE EASTE...
# 8   The text in the image is:\n\npopchips\nPopped...
# 9   The text on the front of the package says: "N...

# %% [markdown]
# #### Tweak the prompt

# %%
# %%bigquery
# SELECT
#   uri,
#   ml_generate_text_llm_result
# FROM
#   ML.GENERATE_TEXT(
#     MODEL remote_models.gemini_pro_vision,
#       TABLE `cs329e-sp2024.airline_stg_ai.snack_product_images`,
#       STRUCT('What is the large text in this image? Return it as json' as prompt,
#         true as flatten_json_output));
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                                uri  \
# 0    gs://cs329e-open-access/images/1001776768.jpg
# 1   gs://cs329e-open-access/images/11300051395.jpg
# 2  gs://cs329e-open-access/images/104770048009.jpg
# 3       gs://cs329e-open-access/images/1142273.jpg
# 4          gs://cs329e-open-access/images/1202.jpg
# 5       gs://cs329e-open-access/images/1020242.jpg
# 6   gs://cs329e-open-access/images/10700450265.jpg
# 7    gs://cs329e-open-access/images/1002485781.jpg
# 8      gs://cs329e-open-access/images/10107043.jpg
# 9      gs://cs329e-open-access/images/11185352.jpg
#
#                          ml_generate_text_llm_result
# 0   ```json\n{\n  "text": "TOPPING CHOCOLATE BALL...
# 1             ```json\n{\n  "text": "Spiced"\n}\n```
# 2             ```json\n{\n  "text": "Haribo"\n}\n```
# 3   ```json\n{\n  "text": "4 BLUEBERRY MUFFINS"\n...
# 4       ```json\n{\n  "text": "Coconut Rock"\n}\n```
# 5           ```json\n{\n  "text": "Cerelene"\n}\n```
# 6      ```json\n{\n  "text": "Jolly Rancher"\n}\n```
# 7   ```json\n{\n  "text": "MEZETE",\n  "confidenc...
# 8           ```json\n{\n  "text": "popchips"\n}\n```
# 9   ```json\n{\n  "text": "PIRE JABUKA MANGO PAPA...

# %%
# %%bigquery
# SELECT
#   uri,
#   ml_generate_text_llm_result
# FROM
#   ML.GENERATE_TEXT(
#     MODEL remote_models.gemini_pro_vision,
#       TABLE `cs329e-sp2024.airline_stg_ai.snack_product_images`,
#         STRUCT('What is the product name in this image? Return it as json' as prompt,
#           True as flatten_json_output));
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                                uri  \
# 0    gs://cs329e-open-access/images/1001776768.jpg
# 1   gs://cs329e-open-access/images/11300051395.jpg
# 2  gs://cs329e-open-access/images/104770048009.jpg
# 3       gs://cs329e-open-access/images/1142273.jpg
# 4          gs://cs329e-open-access/images/1202.jpg
# 5       gs://cs329e-open-access/images/1020242.jpg
# 6   gs://cs329e-open-access/images/10700450265.jpg
# 7    gs://cs329e-open-access/images/1002485781.jpg
# 8      gs://cs329e-open-access/images/10107043.jpg
# 9      gs://cs329e-open-access/images/11185352.jpg
#
#                          ml_generate_text_llm_result
# 0   ```json\n{\n  "product_name": "Topping Chocol...
# 1   ```json\n{\n  "product_name": "Spiced Jelly B...
# 2   ```json\n{\n  "product_name": "Haribo Panda P...
# 3   ```json\n{\n  "product_name": "4 Blueberry Mu...
# 4   ```json\n{\n  "product_name": "Coconut Rock"\...
# 5   ```json\n{\n  "product_name": "Galettes"\n}\n```
# 6   ```json\n{\n  "product_name": "Jolly Rancher ...
# 7   ```json\n{\n  "product_name": "Hummus with Br...
# 8   ```json\n{\n  "product_name": "Sea Salt & Vin...
# 9   ```json\n{\n  "product_name": "Nutrilab Pire ...

# %%
# %%bigquery
# CREATE or REPLACE TABLE airline_stg_ai.product_name_predictions_raw_10 AS
# SELECT
#   uri,
#   ml_generate_text_llm_result
# FROM
#   ML.GENERATE_TEXT(
#     MODEL remote_models.gemini_pro_vision,
#         TABLE `cs329e-sp2024.airline_stg_ai.snack_product_images`,
#           STRUCT('What is the product name in this image? Return it as json' as prompt,
#           True as flatten_json_output));
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Format the json

# %%
# %%bigquery
#   create or replace table airline_stg_ai.product_name_predictions_formatted_10 as
#     select split(replace(uri, 'gs://cs329e-open-access/images/', ''), '.')[0] as snack_id, uri, trim(replace(replace(replace(ml_generate_text_llm_result, '```json', ''), '```', ''), '\n', '')) as ml_generate_text_llm_result
#     from airline_stg_ai.product_name_predictions_raw_10
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select s.snack_id, s.product_name, p.snack_id, p.ml_generate_text_llm_result, s.data_source
# from airline_stg.Snack s join airline_stg_ai.product_name_predictions_formatted_10 p
# on s.snack_id = p.snack_id
# order by s.snack_id
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        snack_id product_name    snack_id_1  \
# 0    1001776768         None    1001776768
# 1    1002485781         None    1002485781
# 2      10107043         None      10107043
# 3       1020242         None       1020242
# 4  104770048009         None  104770048009
# 5   10700450265         None   10700450265
# 6      11185352         None      11185352
# 7   11300051395         None   11300051395
# 8       1142273         None       1142273
# 9          1202         None          1202
#
#                          ml_generate_text_llm_result      data_source
# 0      {  "product_name": "Topping Chocolate Balls"}  open_food_facts
# 1      {  "product_name": "Hummus with Breadsticks"}  open_food_facts
# 2  {  "product_name": "Sea Salt & Vinegar Popchips"}  open_food_facts
# 3                     {  "product_name": "Galettes"}  open_food_facts
# 4             {  "product_name": "Haribo Panda Pik"}  open_food_facts
# 5  {  "product_name": "Jolly Rancher Sour Surge H...  open_food_facts
# 6  {  "product_name": "Nutrilab Pire Jabuka Mango...  open_food_facts
# 7       {  "product_name": "Spiced Jelly Bird Eggs"}  open_food_facts
# 8          {  "product_name": "4 Blueberry Muffins"}  open_food_facts
# 9                 {  "product_name": "Coconut Rock"}  open_food_facts

# %% [markdown]
# #### Update the original table with the product names

# %%
# %%bigquery
# update airline_stg.Snack s
#   set product_name = (select json_value(ml_generate_text_llm_result, '$.product_name')
#     from airline_stg_ai.product_name_predictions_formatted_10 where snack_id = s.snack_id)
#   where 1=1
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select s.snack_id, s.product_name, p.snack_id, p.ml_generate_text_llm_result, s.data_source
# from airline_stg.Snack s join airline_stg_ai.product_name_predictions_formatted_10 p
# on s.snack_id = p.snack_id
# order by s.snack_id
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        snack_id                              product_name    snack_id_1  \
# 0    1001776768                   Topping Chocolate Balls    1001776768
# 1    1002485781                   Hummus with Breadsticks    1002485781
# 2      10107043               Sea Salt & Vinegar Popchips      10107043
# 3       1020242                                  Galettes       1020242
# 4  104770048009                          Haribo Panda Pik  104770048009
# 5   10700450265       Jolly Rancher Sour Surge Hard Candy   10700450265
# 6      11185352  Nutrilab Pire Jabuka Mango Papaja Banana      11185352
# 7   11300051395                    Spiced Jelly Bird Eggs   11300051395
# 8       1142273                       4 Blueberry Muffins       1142273
# 9          1202                              Coconut Rock          1202
#
#                          ml_generate_text_llm_result         data_source
# 0      {  "product_name": "Topping Chocolate Balls"}  open_food_facts_ai
# 1      {  "product_name": "Hummus with Breadsticks"}  open_food_facts_ai
# 2  {  "product_name": "Sea Salt & Vinegar Popchips"}  open_food_facts_ai
# 3                     {  "product_name": "Galettes"}  open_food_facts_ai
# 4             {  "product_name": "Haribo Panda Pik"}  open_food_facts_ai
# 5  {  "product_name": "Jolly Rancher Sour Surge H...  open_food_facts_ai
# 6  {  "product_name": "Nutrilab Pire Jabuka Mango...  open_food_facts_ai
# 7       {  "product_name": "Spiced Jelly Bird Eggs"}  open_food_facts_ai
# 8          {  "product_name": "4 Blueberry Muffins"}  open_food_facts_ai
# 9                 {  "product_name": "Coconut Rock"}  open_food_facts_ai

# %%
# %%bigquery
# update airline_stg.Snack
#   set data_source = 'open_food_facts_ai'
#     where snack_id in (select snack_id from airline_stg_ai.product_name_predictions_formatted_10)
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select *
# from airline_stg.Snack
# where snack_id in (select snack_id from airline_stg_ai.product_name_predictions_formatted_10)
# order by snack_id
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        snack_id                                                url  \
# 0    1001776768  http://world-en.openfoodfacts.org/product/1001...
# 1    1002485781  http://world-en.openfoodfacts.org/product/1002...
# 2      10107043  http://world-en.openfoodfacts.org/product/1010...
# 3       1020242  http://world-en.openfoodfacts.org/product/1020242
# 4  104770048009  http://world-en.openfoodfacts.org/product/0104...
# 5   10700450265  http://world-en.openfoodfacts.org/product/0010...
# 6      11185352  http://world-en.openfoodfacts.org/product/1118...
# 7   11300051395  http://world-en.openfoodfacts.org/product/0011...
# 8       1142273  http://world-en.openfoodfacts.org/product/0114...
# 9          1202  http://world-en.openfoodfacts.org/product/1202...
#
#                                product_name               brands  \
# 0                   Topping Chocolate Balls               Nestlé
# 1                   Hummus with Breadsticks                 None
# 2               Sea Salt & Vinegar Popchips             Popchips
# 3                                  Galettes                 None
# 4                          Haribo Panda Pik               Haribo
# 5       Jolly Rancher Sour Surge Hard Candy  The Hershey Company
# 6  Nutrilab Pire Jabuka Mango Papaja Banana          nutrino lab
# 7                    Spiced Jelly Bird Eggs              Brach's
# 8                       4 Blueberry Muffins       By Sainsbury's
# 9                              Coconut Rock                fanny
#
#                                           categories  \
# 0  Botanas, Snacks dulces, Cacao y sus productos,...
# 1                               Snacks, Snacks salés
# 2  Plant-based foods and beverages, Plant-based f...
# 3    Snacks,Sweet snacks,Biscuits and cakes,Biscuits
# 4        Snacks, Snacks sucrés, Confiseries, Bonbons
# 5     Snacks, Sweet snacks, Confectioneries, Candies
# 6  Plant-based foods and beverages, Plant-based f...
# 7                 Snacks, Snacks sucrés, Confiseries
# 8  Snacks,Snacks sucrés,Biscuits et gâteaux,Gâtea...
# 9  Snacks, Snacks sucrés, Biscuits et gâteaux, Pâ...
#
#                     countries_en  \
# 0                         France
# 1                         France
# 2                 United Kingdom
# 3                           None
# 4                         France
# 5                       Pakistan
# 6  Bosnia and Herzegovina,Serbia
# 7           France,United States
# 8                  New Caledonia
# 9               France,Sri Lanka
#
#                                     ingredients_text  \
# 0  Chocolate con leche [azúcar, cacao, leche desn...
# 1                                               None
# 2                                               None
# 3  Wheat flour, sugar, vegetable fat (palm), inve...
# 4                                               None
# 5                                               None
# 6                                               None
# 7  Sugar, corn syrup, modified food starch (corn)...
# 8                                               None
# 9  DESICCATED COCONUT SUGAR, CARDAMOM POWDER, ART...
#
#                                            image_url  \
# 0  https://images.openfoodfacts.org/images/produc...
# 1  https://images.openfoodfacts.org/images/produc...
# 2  https://images.openfoodfacts.org/images/produc...
# 3  https://images.openfoodfacts.org/images/produc...
# 4  https://images.openfoodfacts.org/images/produc...
# 5  https://images.openfoodfacts.org/images/produc...
# 6  https://images.openfoodfacts.org/images/produc...
# 7  https://images.openfoodfacts.org/images/produc...
# 8  https://images.openfoodfacts.org/images/produc...
# 9  https://images.openfoodfacts.org/images/produc...
#
#                created_time        last_modified_time         data_source  \
# 0 2022-11-05 16:43:09+00:00 2023-07-01 21:40:44+00:00  open_food_facts_ai
# 1 2023-07-14 10:10:21+00:00 2023-08-28 17:18:46+00:00  open_food_facts_ai
# 2 2023-09-07 11:59:45+00:00 2023-11-07 16:48:18+00:00  open_food_facts_ai
# 3 2023-12-22 19:05:21+00:00 2023-12-22 19:10:26+00:00  open_food_facts_ai
# 4 2023-03-16 12:36:15+00:00 2023-05-24 10:50:23+00:00  open_food_facts_ai
# 5 2019-10-17 20:41:40+00:00 2023-10-08 16:51:30+00:00  open_food_facts_ai
# 6 2021-04-01 16:21:52+00:00 2022-04-01 11:52:00+00:00  open_food_facts_ai
# 7 2017-03-30 17:02:35+00:00 2023-04-28 14:33:17+00:00  open_food_facts_ai
# 8 2019-11-16 20:17:31+00:00 2023-06-28 01:50:34+00:00  open_food_facts_ai
# 9 2019-09-03 08:44:53+00:00 2022-02-11 03:44:44+00:00  open_food_facts_ai
#
#                          load_time subcategory language
# 0 2024-02-03 19:40:10.880358+00:00        None     None
# 1 2024-02-03 19:40:10.880358+00:00        None     None
# 2 2024-02-03 19:40:10.880358+00:00        None     None
# 3 2024-02-03 19:40:10.880358+00:00        None     None
# 4 2024-02-03 19:40:10.880358+00:00        None     None
# 5 2024-02-03 19:40:10.880358+00:00        None     None
# 6 2024-02-03 19:40:10.880358+00:00        None     None
# 7 2024-02-03 19:40:10.880358+00:00        None     None
# 8 2024-02-03 19:40:10.880358+00:00        None     None
# 9 2024-02-03 19:40:10.880358+00:00        None     None

# %% [markdown]
# #### Apply at larger scale

# %% [markdown]
# ##### Download the image and copy it into the GCS bucket. Make sure that the file name of the image contains the snack_id

# %%
import requests, os
from google.cloud import bigquery
from google.cloud import storage

bq_client = bigquery.Client()
storage_client = storage.Client()

bucket_name = "cs329e-open-access"
bucket = storage_client.get_bucket(bucket_name)

sql = "select snack_id, image_url from airline_stg.Snack where product_name is null and snack_id != '0' and image_url is not null order by snack_id limit 10"

rows = bq_client.query(sql).result()

for row in rows:
  snack_id = row["snack_id"]
  image_url = row["image_url"].strip()

  image_content = requests.get(image_url).content
  image_name = "{}.jpg".format(snack_id)
  image_file = open(image_name,'wb')
  image_file.write(image_content)
  image_file.close()

  blob = bucket.blob("images/" + image_name)
  blob.upload_from_filename("/content/" + image_name) # Colab places the downloaded image in the /content folder

  os.remove("/content/" + image_name)

# %% [markdown]
# ##### Re-run the cells in the previous sections of Part 3 to re-process the full batch of images

# %% [markdown]
# #### Part 4: Merge changes into target table

# %%
# %%bigquery
# alter table airline_csp.Snack
#   add column subcategory string;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# alter table airline_csp.Snack
#   add column language string;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*) as num_records
# from airline_csp.Snack
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    num_records
# 0       226780

# %%
# %%bigquery
# select count(*) as num_updates
# from airline_csp.Snack t join airline_stg.Snack s
# on t.snack_id = s.snack_id
# where t.status_flag = true
# and (s.product_name is not null and t.product_name is null
# or s.subcategory is not null and t.subcategory is null
# or s.language is not null and t.language is null);
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    num_updates
# 0           20

# %%
# %%bigquery
# declare current_ts TIMESTAMP;
# set current_ts = current_timestamp();
#
# create temp table updates as
#   select s.*
#   from airline_csp.Snack t join airline_stg.Snack s
#   on t.snack_id = s.snack_id
#   where t.status_flag = true
#   and (s.product_name is not null and t.product_name is null
#   or s.subcategory is not null and t.subcategory is null
#   or s.language is not null and t.language is null);
#
# update airline_csp.Snack
# set discontinue_time = timestamp_sub(current_ts, interval 1 second), status_flag = false
# where snack_id in (select snack_id from updates);
#
# insert into airline_csp.Snack
#   (snack_id, url, product_name, brands, categories, countries_en, ingredients_text, image_url,
#     subcategory, language, created_time, last_modified_time, data_source, load_time, effective_time, status_flag)
#     (select snack_id, url, product_name, brands, categories, countries_en, ingredients_text, image_url,
#       subcategory, language, created_time, last_modified_time, data_source, load_time, current_ts, true
#       from updates);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*) as num_records
# from airline_csp.Snack
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    num_records
# 0       226800
