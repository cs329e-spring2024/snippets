# %% [markdown]
# # Catchall Staging

# %% [markdown]
# This notebook creates the Meal and Snack tables in the staging area. Both tables in the raw area contain a significant number of duplicate records. We first determine which fields are duplicated and then decide how to get rid of them when creating the staging table

# %% [markdown]
# # Meal

# %%
# %%bigquery
# select * from airline_raw.meals
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    meal_id                   meal_name  \
# 0    52968  Mbuzi Choma (Roasted Goat)
# 1    52968  Mbuzi Choma (Roasted Goat)
# 2    52968  Mbuzi Choma (Roasted Goat)
# 3    52968  Mbuzi Choma (Roasted Goat)
# 4    52968  Mbuzi Choma (Roasted Goat)
#
#                                           meal_image cat_name      tags  \
# 0  https://www.themealdb.com/images/media/meals/c...     Goat  BBQ,Meat
# 1  https://www.themealdb.com/images/media/meals/c...     Goat  BBQ,Meat
# 2  https://www.themealdb.com/images/media/meals/c...     Goat  BBQ,Meat
# 3  https://www.themealdb.com/images/media/meals/c...     Goat  BBQ,Meat
# 4  https://www.themealdb.com/images/media/meals/c...     Goat  BBQ,Meat
#
#      area ingredient1 ingredient2 ingredient3 ingredient4 ingredient5 source  \
# 0  Kenyan   Goat Meat  Corn Flour    Tomatoes        Salt       Onion   None
# 1  Kenyan   Goat Meat  Corn Flour    Tomatoes        Salt       Onion   None
# 2  Kenyan   Goat Meat  Corn Flour    Tomatoes        Salt       Onion   None
# 3  Kenyan   Goat Meat  Corn Flour    Tomatoes        Salt       Onion   None
# 4  Kenyan   Goat Meat  Corn Flour    Tomatoes        Salt       Onion   None
#
#   youtube                        load_time
# 0    None 2024-01-26 22:24:02.252144+00:00
# 1    None 2024-01-26 22:24:02.252144+00:00
# 2    None 2024-01-26 22:24:02.252144+00:00
# 3    None 2024-01-26 22:24:02.252144+00:00
# 4    None 2024-01-26 22:24:02.252144+00:00

# %%
# %%bigquery
# select (select count(*) from airline_raw.meals) as raw_meal_total_count,
#   (select count(distinct meal_id) from airline_raw.meals) as raw_meal_distinct_count
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    raw_meal_total_count  raw_meal_distinct_count
# 0                  3322                      302

# %% [markdown]
# To place the `data_source` field before the `load_time` field, we use the `except` function.

# %%
# %%bigquery
# create or replace table airline_stg.Meal as
#   select distinct * except(load_time), 'mealdb' as data_source, load_time
#   from airline_raw.meals
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select * from airline_stg.Meal
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    meal_id                       meal_name  \
# 0    52827             Massaman Beef curry
# 1    52979  Bitterballen (Dutch meatballs)
# 2    53006                        Moussaka
# 3    53000        Vegetable Shepherd's Pie
# 4    52781                      Irish stew
#
#                                           meal_image cat_name  \
# 0  https://www.themealdb.com/images/media/meals/t...     Beef
# 1  https://www.themealdb.com/images/media/meals/l...     Beef
# 2  https://www.themealdb.com/images/media/meals/c...     Beef
# 3  https://www.themealdb.com/images/media/meals/w...     Beef
# 4  https://www.themealdb.com/images/media/meals/s...     Beef
#
#                                  tags   area  ingredient1      ingredient2  \
# 0                               Curry   Thai      Peanuts    Coconut cream
# 1  DinnerParty,HangoverFood,Alcoholic  Dutch       Butter            Flour
# 2                                None  Greek         Beef        Aubergine
# 3                           Alcoholic  Irish     Potatoes   Small Potatoes
# 4                           Stew,Meat  Irish  whole wheat  lamb loin chops
#
#             ingredient3 ingredient4    ingredient5  \
# 0  Massaman curry paste        Beef       Potatoes
# 1            Beef Stock       Onion        Parsley
# 2          Greek Yogurt         Egg       Parmesan
# 3         Salted Butter   Mushrooms  Brown Lentils
# 4             olive oil    shallots        carrots
#
#                                               source  \
# 0  https://www.bbcgoodfood.com/recipes/420631/bee...
# 1  https://www.holland.com/global/tourism/informa...
# 2  https://www.bbcgoodfood.com/recipes/must-make-...
# 3                                               None
# 4  http://www.ottolenghi.co.uk/recipes/meat/irish...
#
#                                        youtube data_source  \
# 0  https://www.youtube.com/watch?v=mVxgZSCU9_g      mealdb
# 1  https://www.youtube.com/watch?v=q8AKfYUtDuM      mealdb
# 2  https://www.youtube.com/watch?v=8U_29i9Qp5U      mealdb
# 3                                         None      mealdb
# 4  https://www.youtube.com/watch?v=kYH2qJXnSMo      mealdb
#
#                          load_time
# 0 2024-01-26 22:24:02.252144+00:00
# 1 2024-01-26 22:24:02.252144+00:00
# 2 2024-01-26 22:24:02.252144+00:00
# 3 2024-01-26 22:24:02.252144+00:00
# 4 2024-01-26 22:24:02.252144+00:00

# %%
# %%bigquery
# select (select count(*) from airline_stg.Meal) as stg_meal_records,
#   (select count(*) from airline_raw.meals) as raw_meal_records
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    stg_meal_records  raw_meal_records
# 0               302              3322

# %% [markdown]
# ## Primary Key

# %%
# %%bigquery
# alter table airline_stg.Meal add primary key (meal_id) not enforced
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select meal_id, count(*) as duplicate_records
# from airline_stg.Meal
# group by meal_id
# having count(*) > 1
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [meal_id, duplicate_records]
# Index: []

# %% [markdown]
# # Snacks

# %%
# %%bigquery
# select * from airline_raw.snacks
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#             code                                                url  \
# 0  8606014406504  http://world-en.openfoodfacts.org/product/8606...
# 1  7311041080993  http://world-en.openfoodfacts.org/product/7311...
# 2  4901561213587  http://world-en.openfoodfacts.org/product/4901...
# 3  5000159504355  http://world-en.openfoodfacts.org/product/5000...
# 4  4009900526838  http://world-en.openfoodfacts.org/product/4009...
#
#                  product_name brands  \
# 0                        None   None
# 1                        None   None
# 2                        焼するめ   None
# 3  Peanut Chocolate Treat Bag   None
# 4                       Minis   None
#
#                                        categories countries_en  \
# 0                                          snacks         None
# 1                                          snacks         None
# 2                      en:Snacks, en:Salty snacks         None
# 3        Snacks, en:Confiseries, en:Snacks sucrés         None
# 4  Snacks, Sweet snacks, Confectioneries, Candies         None
#
#                                     ingredients_text  \
# 0                                                idk
# 1  Hvetemel, salt 3,6 %, rapsolje, surhetsreguler...
# 2  いか (中国)、砂糖、食塩、乳糖/ソルビット、調味料(ア ミノ酸等)、酸味料、リン酸塩(Na...
# 3    R zoz 82 20:00 ¥2170/20 000159 504355&quot;&gt;
# 4  sugar, glucose syrup, palm fat, acid citric ac...
#
#                                            image_url  \
# 0  https://images.openfoodfacts.org/images/produc...
# 1  https://images.openfoodfacts.org/images/produc...
# 2                                               None
# 3  https://images.openfoodfacts.org/images/produc...
# 4  https://images.openfoodfacts.org/images/produc...
#
#                          load_time
# 0 2024-02-03 17:32:09.469541+00:00
# 1 2024-02-03 17:32:09.469541+00:00
# 2 2024-02-03 17:32:09.469541+00:00
# 3 2024-02-03 17:32:09.469541+00:00
# 4 2024-02-03 17:32:09.469541+00:00

# %%
# %%bigquery
# select (select count(*) from airline_raw.snacks) as raw_snack_total_count,
#   (select count(distinct code) from airline_raw.snacks) as raw_snack_distinct_count,
#     (select count(*) - count(distinct code) from airline_raw.snacks) as duplicate_count
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    raw_snack_total_count  raw_snack_distinct_count  duplicate_count
# 0                 226831                    226780               51

# %%
# %%bigquery
# select code, count(*) as duplicate_count
# from airline_raw.snacks
# group by code
# having count(*) > 1
# order by code
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                      code  duplicate_count
# 0  1.0841052523204611e+21                2
# 1                      10                2
# 2                 1142273                2
# 3                   11778                2
# 4                  130509                2

# %%
# %%bigquery
# select code, created_datetime, last_modified_datetime from airline_raw.snacks
# where code in ('10', '11778', '130509', '502566', '783033')
# order by code, last_modified_datetime desc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      code          created_datetime    last_modified_datetime
# 0      10 2019-06-28 13:22:36+00:00 2023-12-16 12:18:25+00:00
# 1      10 2016-10-20 07:19:01+00:00 2023-04-29 11:35:19+00:00
# 2   11778 2016-09-21 20:19:09+00:00 2022-02-11 08:26:09+00:00
# 3   11778 2017-03-31 15:58:35+00:00 2022-02-10 15:27:26+00:00
# 4  130509 2019-06-28 10:16:34+00:00 2023-09-06 12:34:25+00:00
# 5  130509 2019-04-23 20:28:51+00:00 2022-02-11 03:38:22+00:00
# 6  502566 2018-04-22 07:47:05+00:00 2023-10-27 10:37:21+00:00
# 7  502566 2021-12-27 11:12:30+00:00 2023-08-25 09:55:29+00:00
# 8  783033 2023-08-27 23:35:42+00:00 2023-10-26 18:47:39+00:00
# 9  783033 2018-03-09 08:51:18+00:00 2023-09-27 11:20:44+00:00

# %% [markdown]
# Use a Window function to [rank](https://cloud.google.com/bigquery/docs/reference/standard-sql/window-function-calls#compute_rank) the snacks within their code by their last modified date. This ranking will allow us to filter out the duplicate snacks.

# %%
# %%bigquery
# select RANK() over (partition by code order by last_modified_datetime desc) AS rank, code, product_name, last_modified_datetime
# from airline_raw.snacks
# where code in ('10', '11778', '130509', '502566')
# order by code;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    rank    code                                product_name  \
# 0     1      10                 Vegan 3K-Protein Cheesecake
# 1     2      10                           Madeleines nature
# 2     1   11778  All Butter Reduced Fat Stem Ginger Cookies
# 3     2   11778                         Stem Ginger Cookies
# 4     1  130509                              Wheat Biscuits
# 5     2  130509                      24 wholewheat biscuits
# 6     1  502566                          Buttery Croissants
# 7     2  502566                       all butter croissants
#
#      last_modified_datetime
# 0 2023-12-16 12:18:25+00:00
# 1 2023-04-29 11:35:19+00:00
# 2 2022-02-11 08:26:09+00:00
# 3 2022-02-10 15:27:26+00:00
# 4 2023-09-06 12:34:25+00:00
# 5 2022-02-11 03:38:22+00:00
# 6 2023-10-27 10:37:21+00:00
# 7 2023-08-25 09:55:29+00:00

# %% [markdown]
# Create the intermediate staging table `snacks` using the `rank()` function:

# %%
# %%bigquery
# create or replace table airline_stg.snacks as
#   select code as snack_id, * except(code, rank, load_time), 'open_food_facts' as data_source, load_time
#   from
#     (select RANK() over (partition by code order by last_modified_datetime desc) AS rank, *
#     from airline_raw.snacks)
#   where rank = 1
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select (select count(*) from airline_stg.snacks) as intermediate_stg_count,
#   (select count(*) from airline_raw.snacks) as raw_count
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    intermediate_stg_count  raw_count
# 0                  226782     226831

# %%
# %%bigquery
# select *
# from airline_stg.snacks
# where snack_id in ('10', '11778', '130509', '502566')
# order by snack_id;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   snack_id                                                url  \
# 0       10  http://world-en.openfoodfacts.org/product/0010...
# 1    11778  http://world-en.openfoodfacts.org/product/0011...
# 2   130509  http://world-en.openfoodfacts.org/product/0013...
# 3   502566  http://world-en.openfoodfacts.org/product/0050...
#
#                                  product_name           brands  \
# 0                 Vegan 3K-Protein Cheesecake           Nutri+
# 1  All Butter Reduced Fat Stem Ginger Cookies  Marks & Spencer
# 2                              Wheat Biscuits   By Sainsbury's
# 3                          Buttery Croissants  Marks & Spencer
#
#                                           categories            countries_en  \
# 0  Snacks, Sweet snacks, Biscuits and cakes, Cake...  France,Germany,Ireland
# 1  Snacks, Snacks sucrés, Biscuits et gâteaux, Bi...   France,United Kingdom
# 2  Plant-based foods and beverages, Plant-based f...          United Kingdom
# 3  Snacks, Sweet snacks, Viennoiseries, Croissant...                  France
#
#                                     ingredients_text  \
# 0                                               None
# 1  Farine de _blé_ (contient _Gluten_) (avec Fari...
# 2  British Wholegrain Wheat (95%), Malted Barley ...
# 3  Not suitabl Wheatflour (contains Gluten). Butt...
#
#                                            image_url  \
# 0  https://images.openfoodfacts.org/images/produc...
# 1  https://images.openfoodfacts.org/images/produc...
# 2  https://images.openfoodfacts.org/images/produc...
# 3                                               None
#
#            created_datetime    last_modified_datetime      data_source  \
# 0 2019-06-28 13:22:36+00:00 2023-12-16 12:18:25+00:00  open_food_facts
# 1 2016-09-21 20:19:09+00:00 2022-02-11 08:26:09+00:00  open_food_facts
# 2 2019-06-28 10:16:34+00:00 2023-09-06 12:34:25+00:00  open_food_facts
# 3 2018-04-22 07:47:05+00:00 2023-10-27 10:37:21+00:00  open_food_facts
#
#                          load_time
# 0 2024-02-03 19:40:10.880358+00:00
# 1 2024-02-03 19:40:10.880358+00:00
# 2 2024-02-03 19:40:10.880358+00:00
# 3 2024-02-03 19:40:10.880358+00:00

# %%
# %%bigquery
# select *
# from airline_stg.snacks
# where snack_id in ('10', '11778', '130509', '502566')
# order by snack_id;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   snack_id                                                url  \
# 0       10  http://world-en.openfoodfacts.org/product/0010...
# 1    11778  http://world-en.openfoodfacts.org/product/0011...
# 2   130509  http://world-en.openfoodfacts.org/product/0013...
# 3   502566  http://world-en.openfoodfacts.org/product/0050...
#
#                                  product_name           brands  \
# 0                 Vegan 3K-Protein Cheesecake           Nutri+
# 1  All Butter Reduced Fat Stem Ginger Cookies  Marks & Spencer
# 2                              Wheat Biscuits   By Sainsbury's
# 3                          Buttery Croissants  Marks & Spencer
#
#                                           categories            countries_en  \
# 0  Snacks, Sweet snacks, Biscuits and cakes, Cake...  France,Germany,Ireland
# 1  Snacks, Snacks sucrés, Biscuits et gâteaux, Bi...   France,United Kingdom
# 2  Plant-based foods and beverages, Plant-based f...          United Kingdom
# 3  Snacks, Sweet snacks, Viennoiseries, Croissant...                  France
#
#                                     ingredients_text  \
# 0                                               None
# 1  Farine de _blé_ (contient _Gluten_) (avec Fari...
# 2  British Wholegrain Wheat (95%), Malted Barley ...
# 3  Not suitabl Wheatflour (contains Gluten). Butt...
#
#                                            image_url  \
# 0  https://images.openfoodfacts.org/images/produc...
# 1  https://images.openfoodfacts.org/images/produc...
# 2  https://images.openfoodfacts.org/images/produc...
# 3                                               None
#
#            created_datetime    last_modified_datetime      data_source  \
# 0 2019-06-28 13:22:36+00:00 2023-12-16 12:18:25+00:00  open_food_facts
# 1 2016-09-21 20:19:09+00:00 2022-02-11 08:26:09+00:00  open_food_facts
# 2 2019-06-28 10:16:34+00:00 2023-09-06 12:34:25+00:00  open_food_facts
# 3 2018-04-22 07:47:05+00:00 2023-10-27 10:37:21+00:00  open_food_facts
#
#                          load_time
# 0 2024-02-03 19:40:10.880358+00:00
# 1 2024-02-03 19:40:10.880358+00:00
# 2 2024-02-03 19:40:10.880358+00:00
# 3 2024-02-03 19:40:10.880358+00:00

# %%
# %%bigquery
# select snack_id, count(*)
# from airline_stg.snacks
# group by snack_id
# having count(*) > 1
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         snack_id  f0_
# 0  8424465927603    2
# 1  7071688002962    2

# %%
# %%bigquery
# select *
# from airline_stg.snacks
# where snack_id in ('8424465927603', '7071688002962')
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         snack_id                                                url  \
# 0  8424465927603  http://world-en.openfoodfacts.org/product/8424...
# 1  8424465927603  http://world-en.openfoodfacts.org/product/8424...
# 2  7071688002962  http://world-en.openfoodfacts.org/product/7071...
# 3  7071688002962  http://world-en.openfoodfacts.org/product/7071...
#
#                      product_name          brands  \
# 0  Croissant Integral Realfooding            None
# 1  Croissant Integral Realfooding            None
# 2             Tortilla Fyldig Ost  Sørlands Chips
# 3             Tortilla Fyldig Ost  Sørlands Chips
#
#                                           categories countries_en  \
# 0     Botanas,Snacks dulces,Viennoiseries,Croissants        Spain
# 1  Botanas, Snacks dulces, Viennoiseries, Croissants        Spain
# 2  Snacks,Salty snacks,Appetizers,Chips and fries...       Norway
# 3  en:Snacks, en:Salty snacks, en:Appetizers, en:...       Norway
#
#                                     ingredients_text  \
# 0  Harina de TRIGO integral 40%, preparado graso ...
# 1  Harina de TRIGO integral 40%, preparado graso ...
# 2  Hvit mais (68 %), solsikkeolje og krydder (glu...
# 3  Hvit mais (68 %), solsikkeolje og krydder (glu...
#
#                                            image_url  \
# 0  https://images.openfoodfacts.org/images/produc...
# 1  https://images.openfoodfacts.org/images/produc...
# 2  https://images.openfoodfacts.org/images/produc...
# 3  https://images.openfoodfacts.org/images/produc...
#
#            created_datetime    last_modified_datetime      data_source  \
# 0 2022-06-10 08:41:42+00:00 2022-06-13 09:01:09+00:00  open_food_facts
# 1 2022-06-10 08:41:42+00:00 2022-06-13 09:01:09+00:00  open_food_facts
# 2 2021-07-08 10:01:18+00:00 2021-07-13 14:26:35+00:00  open_food_facts
# 3 2021-07-08 10:01:18+00:00 2021-07-13 14:26:35+00:00  open_food_facts
#
#                          load_time
# 0 2024-02-03 19:40:10.880358+00:00
# 1 2024-02-03 19:40:10.880358+00:00
# 2 2024-02-03 19:40:10.880358+00:00
# 3 2024-02-03 19:40:10.880358+00:00

# %%
# %%bigquery
#   select distinct * except(categories)
#   from airline_stg.snacks
#   where snack_id in ('8424465927603', '7071688002962')
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         snack_id                                                url  \
# 0  8424465927603  http://world-en.openfoodfacts.org/product/8424...
# 1  7071688002962  http://world-en.openfoodfacts.org/product/7071...
#
#                      product_name          brands countries_en  \
# 0  Croissant Integral Realfooding            None        Spain
# 1             Tortilla Fyldig Ost  Sørlands Chips       Norway
#
#                                     ingredients_text  \
# 0  Harina de TRIGO integral 40%, preparado graso ...
# 1  Hvit mais (68 %), solsikkeolje og krydder (glu...
#
#                                            image_url  \
# 0  https://images.openfoodfacts.org/images/produc...
# 1  https://images.openfoodfacts.org/images/produc...
#
#            created_datetime    last_modified_datetime      data_source  \
# 0 2022-06-10 08:41:42+00:00 2022-06-13 09:01:09+00:00  open_food_facts
# 1 2021-07-08 10:01:18+00:00 2021-07-13 14:26:35+00:00  open_food_facts
#
#                          load_time
# 0 2024-02-03 19:40:10.880358+00:00
# 1 2024-02-03 19:40:10.880358+00:00

# %%
# %%bigquery
#   select categories
#   from airline_stg.snacks
#   where snack_id in ('8424465927603', '7071688002962')
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                           categories
# 0     Botanas,Snacks dulces,Viennoiseries,Croissants
# 1  Botanas, Snacks dulces, Viennoiseries, Croissants
# 2  Snacks,Salty snacks,Appetizers,Chips and fries...
# 3  en:Snacks, en:Salty snacks, en:Appetizers, en:...

# %%
# %%bigquery
# select snack_id, count(*)
# from airline_stg.Snack
# group by snack_id
# having count(*) > 1
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         snack_id  f0_
# 0  8424465927603    2
# 1  7071688002962    2

# %%
# %%bigquery
# select RANK() over (partition by snack_id order by categories desc) AS rank, snack_id, product_name, categories, last_modified_datetime
# from airline_stg.snacks
# where snack_id in ('8424465927603', '7071688002962')
# order by snack_id;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    rank       snack_id                    product_name  \
# 0     1  7071688002962             Tortilla Fyldig Ost
# 1     2  7071688002962             Tortilla Fyldig Ost
# 2     1  8424465927603  Croissant Integral Realfooding
# 3     2  8424465927603  Croissant Integral Realfooding
#
#                                           categories    last_modified_datetime
# 0  en:Snacks, en:Salty snacks, en:Appetizers, en:... 2021-07-13 14:26:35+00:00
# 1  Snacks,Salty snacks,Appetizers,Chips and fries... 2021-07-13 14:26:35+00:00
# 2     Botanas,Snacks dulces,Viennoiseries,Croissants 2022-06-13 09:01:09+00:00
# 3  Botanas, Snacks dulces, Viennoiseries, Croissants 2022-06-13 09:01:09+00:00

# %%
# %%bigquery
# select RANK() over (partition by snack_id order by categories desc) AS rank, *
# from airline_stg.snacks
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    rank     snack_id                                                url  \
# 0     1  10001163956  http://world-en.openfoodfacts.org/product/0010...
# 1     1  10300878810  http://world-en.openfoodfacts.org/product/0010...
# 2     1  10300894407  http://world-en.openfoodfacts.org/product/0010...
# 3     1  10300964896  http://world-en.openfoodfacts.org/product/0010...
# 4     1  10374420618  http://world-en.openfoodfacts.org/product/0010...
#
#                              product_name                         brands  \
# 0            Crunchy banana chocolate bar                 B R Group Inc.
# 1                          Glazed Walnuts                        Emerald
# 2                                 Cashews                           None
# 3  Emerald, nutty bites, lemon poppy seed  Emerald,  Diamond Foods  Inc.
# 4                              Cheesecake         The Father's Table Llc
#
#                                           categories   countries_en  \
# 0  Snacks, Sweet snacks, Cocoa and its products, ...  United States
# 1                                             Snacks  United States
# 2                                             Snacks  United States
# 3  Snacks, Sweet snacks, Biscuits and cakes, Bisc...  United States
# 4    Snacks, Sweet snacks, Biscuits and cakes, Cakes  United States
#
#                                     ingredients_text image_url  \
# 0      Cacao, organic coconut sugar, organic banana.      None
# 1  Walnuts, sugar, corn syrup, sesame seeds, salt...      None
# 2  Cashews, vegetable oil (contains one or more o...      None
# 3  Cashews, almonds, cane sugar, rice syrup, puff...      None
# 4  Cream cheese [cultured cream and milk, salt, x...      None
#
#            created_datetime    last_modified_datetime      data_source  \
# 0 2017-03-10 10:58:13+00:00 2020-04-23 09:51:16+00:00  open_food_facts
# 1 2017-03-10 08:39:41+00:00 2020-04-23 07:30:27+00:00  open_food_facts
# 2 2020-04-23 17:06:24+00:00 2020-04-23 17:06:24+00:00  open_food_facts
# 3 2017-03-09 14:54:21+00:00 2020-04-22 19:45:23+00:00  open_food_facts
# 4 2017-03-10 10:39:46+00:00 2021-08-05 05:01:10+00:00  open_food_facts
#
#                          load_time
# 0 2024-02-03 19:40:10.880358+00:00
# 1 2024-02-03 19:40:10.880358+00:00
# 2 2024-02-03 19:40:10.880358+00:00
# 3 2024-02-03 19:40:10.880358+00:00
# 4 2024-02-03 19:40:10.880358+00:00

# %%
# %%bigquery
# create or replace table airline_stg.Snack as
#   select snack_id, url, product_name, brands, categories, countries_en, ingredients_text, image_url,
#     created_datetime as created_time, last_modified_datetime as last_modified_time
#   from
#     (select RANK() over (partition by snack_id order by categories desc) AS rank, *
#     from airline_stg.snacks)
#   where rank = 1
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select snack_id, count(*) as duplicate_pk
# from airline_stg.Snack
# group by snack_id
# having count(*) > 1
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [snack_id, duplicate_pk]
# Index: []

# %%
# %%bigquery
# select (select count(*) from airline_stg.snacks) as intermediate_stg_count,
#   (select count(*) from airline_stg.Snack) as final_stg_count
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    intermediate_stg_count  final_stg_count
# 0                  226782           226780

# %% [markdown]
# ## Primary Key

# %%
# %%bigquery
# alter table airline_stg.Snack add primary key(snack_id) not enforced
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select snack_id, count(*) as duplicate_records
# from airline_stg.Snack
# group by snack_id
# having count(*) > 1
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [snack_id, duplicate_records]
# Index: []

# %% [markdown]
# ## Cleanup

# %%
# %%bigquery
# drop table airline_stg.snacks
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []
