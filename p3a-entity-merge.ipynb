# %% [markdown]
# # Entity Merge

# %% [markdown]
# In this notebook, we merge the bird_airport records with the icao and state values when those are present in the `faker_airports` table. We output a new table, `airline_stg.Airport`, with the merged results.

# %%
# %%bigquery
# select * from airline_stg.bird_airports
# order by code
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   code                     name              city state country
# 0  01A     Afognak Lake Airport      Afognak Lake    AK      US
# 1  03A  Bear Creek Mining Strip  Granite Mountain    AK      US
# 2  04A          Lik Mining Camp               Lik    AK      US
# 3  05A     Little Squaw Airport      Little Squaw    AK      US
# 4  06A             Kizhuyak Bay          Kizhuyak    AK      US

# %%
# %%bigquery
# select * from airline_raw.faker_airports
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                  airport iata  icao           city        state country  \
# 0       Tarapoto airport  TPP  None       Tarapoto   San Martin    Peru
# 1         El Loa airport  CJC  None         Calama  Antofagasta   Chile
# 2     La Florida airport  LSC  None  Compañía Alta     Coquimbo   Chile
# 3  Hefei-Luogang airport  HFE  None          Hefei        Anhui   China
# 4                Guizhou  KWE  None        Guiyang      Guizhou   China
#
#                          load_time
# 0 2024-01-22 02:03:23.692748+00:00
# 1 2024-01-22 02:03:23.692748+00:00
# 2 2024-01-22 02:03:23.692748+00:00
# 3 2024-01-22 02:03:23.692748+00:00
# 4 2024-01-22 02:03:23.692748+00:00

# %%
# %%bigquery
# select (select count(*) from airline_raw.faker_airports
#         where icao is not null) as faker_icao_count,
#         (select count(*) from airline_stg.bird_airports) as bird_count
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    faker_icao_count  bird_count
# 0               326        6510

# %%
# %%bigquery
#   select count(*) as state_count
#   from airline_stg.bird_airports b
#   join airline_raw.faker_airports f
#   on b.code = f.iata
#   where f.state is not null
#   and b.state is null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    state_count
# 0          319

# %% [markdown]
# Note: `faker_airports` has 319 states which are missing from `bird_airports`. We will merge those values in the **state** section of this notebook.

# %% [markdown]
# # icao

# %% [markdown]
# Merge `faker_airports.icao` into `bird_airports.icao` to enrich the airport records with the icao code when it is missing from `bird_airports`. Only a small subset will be enriched (326/6510).

# %%
# %%bigquery
#   select b.*, f.icao from airline_stg.bird_airports b
#   join airline_raw.faker_airports f
#   on b.code = f.iata
#   where f.icao is not null
#   limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   code                            name      city state country  icao
# 0  THR          Mehrabad International    Tehran  None    Iran  OIII
# 1  MCT            Muscat International    Muscat  None    Oman  OOMS
# 2  JUL                 Juliaca Airport   Juliaca  None    Peru  SPJL
# 3  LIM      Jorge Chavez International      Lima  None    Peru  SPIM
# 4  AQP  Rodriguez Ballon International  Arequipa  None    Peru  SPQU

# %%
# %%bigquery
#   create or replace table airline_stg.Airport as
#     select b.code as iata, f.icao as icao,
#     b.name, b.city, b.state, b.country, b.data_source, b.load_time
#     from airline_stg.bird_airports b
#     left join airline_raw.faker_airports f
#     on b.code = f.iata;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Note: the left join is important to avoid losing records from `airline_stg.bird_airports`.

# %%
# %%bigquery
#   select * from airline_stg.Airport
#   where icao is not null
#   limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   iata  icao                                           name      city state  \
# 0  THR  OIII                         Mehrabad International    Tehran  None
# 1  MCT  OOMS                           Muscat International    Muscat  None
# 2  LIM  SPIM                     Jorge Chavez International      Lima  None
# 3  AQP  SPQU                 Rodriguez Ballon International  Arequipa  None
# 4  CIX  SPHI  Capt. Jose A. Quinones Gonzales International  Chiclayo  None
#
#   country data_source                        load_time
# 0    Iran        bird 2024-01-26 22:23:29.069725+00:00
# 1    Oman        bird 2024-01-26 22:23:29.069725+00:00
# 2    Peru        bird 2024-01-26 22:23:29.069725+00:00
# 3    Peru        bird 2024-01-26 22:23:29.069725+00:00
# 4    Peru        bird 2024-01-26 22:23:29.069725+00:00

# %% [markdown]
# The only problem is that the `data_source` should no longer be "bird" for the merged records. Update them to "bird_faker", to indicate that they came from both data sources:

# %%
# %%bigquery
# update airline_stg.Airport set data_source = 'bird_faker' where icao is not null;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
#   select * from airline_stg.Airport
#   where icao is not null
#   limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   iata  icao                            name            city state country  \
# 0  STL  KSTL  St Louis Lambert International       St. Louis    MO      US
# 1  EWR  KEWR    Newark Liberty International          Newark    NJ      US
# 2  LGA  KLGA                       LaGuardia        New York    NY      US
# 3  HOU  KHOU                 William P Hobby         Houston    TX      US
# 4  SLC  KSLC    Salt Lake City International  Salt Lake City    UT      US
#
#   data_source                        load_time
# 0  bird_faker 2024-01-26 22:23:29.069725+00:00
# 1  bird_faker 2024-01-26 22:23:29.069725+00:00
# 2  bird_faker 2024-01-26 22:23:29.069725+00:00
# 3  bird_faker 2024-01-26 22:23:29.069725+00:00
# 4  bird_faker 2024-01-26 22:23:29.069725+00:00

# %%
# %%bigquery
#   select count(*) icao_count
#   from airline_stg.Airport
#   where icao is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    icao_count
# 0         326

# %%
# %%bigquery
#   select (select count(*) from airline_stg.Airport) as merged_table_count,
#   (select count(*) from airline_stg.bird_airports) as bird_table_count
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    merged_table_count  bird_table_count
# 0                6510              6510

# %% [markdown]
# # state

# %% [markdown]
# Find all the `Airport` records with a null state, whose state exists in `faker_airports`. Merge `faker_airports.state` into `Airport.state` to enrich those records. Only a small subset of the records will be enriched (319/6510).

# %%
# %%bigquery
# select a.*, f.state state_from_faker
# from airline_raw.faker_airports f
# join airline_stg.Airport a
# on f.iata = a.iata
# where f.state is not null
# and a.state is null
# order by iata
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   iata  icao                      name               city state    country  \
# 0  ACE  GCRR                 Lanzarote           Arrecife  None      Spain
# 1  ADZ  SKSP     Gustavo Rojas Pinilla  San Andres Island  None   Colombia
# 2  AEP  SABE  Aeroparque Jorge Newbery       Buenos Aires  None  Argentina
# 3  AER  URSS       Adler/Sochi Airport        Adler/Sochi  None     Russia
# 4  AGP  LEMG            Malaga Airport             Malaga  None      Spain
#
#   data_source                        load_time          state_from_faker
# 0  bird_faker 2024-01-26 22:23:29.069725+00:00            Canary Islands
# 1  bird_faker 2024-01-26 22:23:29.069725+00:00  San Andres y Providencia
# 2  bird_faker 2024-01-26 22:23:29.069725+00:00    Ciudad de Buenos Aires
# 3  bird_faker 2024-01-26 22:23:29.069725+00:00        Krasnodarskiy Kray
# 4  bird_faker 2024-01-26 22:23:29.069725+00:00                 Andalucia

# %%
# %%bigquery
#   update airline_stg.Airport a set state =
#     (select distinct state
#      from airline_raw.faker_airports f
#      where f.iata = a.iata
#      and f.state is not null), data_source = 'bird_faker'
#   where state is null;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
#   select * from airline_stg.Airport
#   where iata in ('ACE', 'ADZ', 'AEP', 'AER', 'AGP')
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   iata  icao                      name               city  \
# 0  AGP  LEMG            Malaga Airport             Malaga
# 1  ACE  GCRR                 Lanzarote           Arrecife
# 2  AER  URSS       Adler/Sochi Airport        Adler/Sochi
# 3  ADZ  SKSP     Gustavo Rojas Pinilla  San Andres Island
# 4  AEP  SABE  Aeroparque Jorge Newbery       Buenos Aires
#
#                       state    country data_source  \
# 0                 Andalucia      Spain  bird_faker
# 1            Canary Islands      Spain  bird_faker
# 2        Krasnodarskiy Kray     Russia  bird_faker
# 3  San Andres y Providencia   Colombia  bird_faker
# 4    Ciudad de Buenos Aires  Argentina  bird_faker
#
#                          load_time
# 0 2024-01-26 22:23:29.069725+00:00
# 1 2024-01-26 22:23:29.069725+00:00
# 2 2024-01-26 22:23:29.069725+00:00
# 3 2024-01-26 22:23:29.069725+00:00
# 4 2024-01-26 22:23:29.069725+00:00

# %% [markdown]
# # Primary Key

# %%
# %%bigquery
# alter table airline_stg.Airport
#   add primary key (iata) not enforced;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select iata, count(*) duplicate_records
# from airline_stg.Airport
# group by iata
# having count(*) > 1
# order by count(*) desc
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [iata, duplicate_records]
# Index: []

# %% [markdown]
# # Foreign Keys

# %%
# %%bigquery
# alter table airline_stg.Flight add foreign key (origin)
#   references airline_stg.Airport (iata) not enforced;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*) as orphan_records
# from airline_stg.Flight
# where origin not in (select iata from airline_stg.Airport)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    orphan_records
# 0               0

# %%
# %%bigquery
# alter table airline_stg.Flight add foreign key (dest)
#   references airline_stg.Airport (iata) not enforced;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select count(*) as orphan_records
# from airline_stg.Flight
# where dest not in (select iata from airline_stg.Airport)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    orphan_records
# 0               0

# %% [markdown]
# # Cleanup

# %%
# %%bigquery
# drop table airline_stg.bird_airports
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []
